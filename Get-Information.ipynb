# %%
import urllib2
import json
import re
import io
import copy
import nltk, re, pprint
import os
import time
import calendar
import datetime
from threading import Thread
from time import sleep

# %%
f = io.open('data.tsv', 'r', encoding='utf-8')
movies = re.findall(r'\w\w\w\w\w\w\w\w\w\tmovie.+\n', f.read())
f.close()
f = io.open('data.tsv', 'r', encoding='utf-8')
documentarys = re.findall(r'\w\w\w\w\w\w\w\w\w\tmovie.+\tDocumentary\n', f.read())
f.close()
f = io.open('data.tsv', 'r', encoding='utf-8')
empty = re.findall(r'\w\w\w\w\w\w\w\w\w\tmovie.+\t\\N\n', f.read())
f.close()

# %%
movieSet = set(movies)
docuSet = set(documentarys)
emptyMovieSet = set(empty)
KunMovies = (movieSet - docuSet) - emptyMovieSet

# %%
f = io.open('Movies.txt', 'w', encoding='utf-8')
for i in KunMovies:
    f.write(i)
f.close()
f = io.open('Movies.txt', 'r', encoding='utf-8')
IMDB = re.findall(r'(\w\w\w\w\w\w\w\w\w).+\n', f.read())

# %%
def threaded_function(arg):
    f = io.open('Done2.txt', 'a', encoding='utf-8')    
    f.writelines(arg + "\n")
    f.close()
    try:
        query = "https://api.themoviedb.org/3/movie/" + arg + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
        wikiresponse = urllib2.urlopen(query)
        sidensJson = json.load(wikiresponse)
        revenue = sidensJson["revenue"]
        if (revenue > 0):
            print "NUMMERET ER " , IMDB.index(arg)
            with open('Testing/' + arg + '.txt', 'w') as outfile:
                json.dump(sidensJson, outfile)
            f = io.open('Success.txt', 'a', encoding='utf-8')    
            f.writelines(arg + "\n")
            f.close()
    except:
        pass

# %%
thread = Thread(target = threaded_function, args = (IMDB[0]))
Threads = []
startTime = calendar.timegm(time.gmtime())
doneList = []
f = io.open('Done.txt', 'r')
doneList = f.readlines()
doneList = [x.strip() for x in doneList] 
f.close()
q = 0
for i in range(0,len(IMDB)):
    try:
        doneList.index(IMDB[i])
    except:
        if (q % 40 == 0 and q != 0):
            for j in range(q-40, q):
                Threads[j].join()
        thread = Thread(target = threaded_function, args = (IMDB[i], ))
        print i
        Threads.append(thread)
        Threads[q].start()

        if (q % 40 == 0 and q != 0):
            for j in Threads:
                j.join()
            slutTime = calendar.timegm(time.gmtime())
            diffTime = slutTime - startTime
            #print "Difftime = " , diffTime
            if (diffTime <= 10):
                strafTid = 12 - diffTime
                #print "Pause = ", strafTid
                time.sleep(strafTid)
            startTime = calendar.timegm(time.gmtime())
        q = q + 1
# Out:
# 0
# 1
# 2
# 3
# 5
# 6
# 9
# 13
# 15
# 17
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 28
# 29
# 33
# 34
# 36
# 37
# 38
# 39
# 40
# 41
# 44
# 45
# 46
# 48
# 49
# 51
# 52
# 54
# 55
# 56
# 57
# 58
# 59
# 63
# 65
# 66
# 67
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 77
# 79
# 80
# 87
# 90
# 95
# 96
# 100
# 102
# 106
# 109
# 113
# 114
# 116
# 117
# 118
# 119
# 120
# 123
# 126
# 128
# 131
# 134
# 136
# 138
# 139
# 140
# 143
# 145
# 148
# 149
# 152
# 153
# 154
# 155
# 157
# 159
# 162
# 164
# 165
# 166
# 167
# 170
# 172
# 173
# 174
# 177
# 178
# 179
# 184
# 185
# 186
# 191
# 192
# 194
# 195
# 197
# 199
# 202
# 203
# 205
# 208
# 209
# 211
# 213
# 214
# 216
# 220
# 221
# 223
# 225
# 228
# 229
# 230
# 232
# 233
# 234
# 235
# 236
# 237
# 239
# 240
# 243
# 244
# 247
# 248
# 251
# 252
# 256
# 257
# 258
# 260
# 261
# 262
# 264
# 266
# 271
# 275
# 278
# 280
# 281
# 283
# 284
# 285
# 290
# 291
# 292
# 293
# 295
# 296
# 298
# 301
# 302
# 303
# 305
# 306
# 308
# 309
# 310
# 311
# 312
# 313
# 315
# 316
# 318
# ...

# %% [markdown]
# <h1> STOP HER

# %%
query = "https://api.themoviedb.org/3/movie/" + IMDB[107] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
wikiresponse = urllib2.urlopen(query)
sidensJson = json.load(wikiresponse)

# %%
with open('Testing/' + IMDB[107] + '.txt', 'w') as outfile:
    json.dump(sidensJson, outfile)

# %%
virkedeDet = 0
filmMedRevenue = []
startTime = calendar.timegm(time.gmtime())
slutTime = 0
print calendar.timegm(time.gmtime())
j = 0
for i in IMDB:
    try:
        query = "https://api.themoviedb.org/3/movie/" + i + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
        wikiresponse = urllib2.urlopen(query)
        sidensJson = json.load(wikiresponse)
        revenue = sidensJson["revenue"]
        if (revenue > 0):
            filmMedRevenue.append(i)
            with open('Testing/' + i + '.txt', 'w') as outfile:
                json.dump(sidensJson, outfile)
        virkedeDet = virkedeDet + 1
    except:
        virkedeDet = virkedeDet + 0
    if (j % 40 == 0 and j != 0):
        slutTime = calendar.timegm(time.gmtime())
        diffTime = slutTime - startTime
        print diffTime
        if (diffTime < 10):
            strafTid = 10 - diffTime
            print "Pause = ", strafTid
            time.sleep(strafTid)
    if (j % 40 == 0 and j != 0):
        startTime = calendar.timegm(time.gmtime())
    if (j =query = "https://api.themoviedb.org/3/movie/" + IMDB[1] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"

sidensJson = json.load(wikiresponse)= 120):
        break
    j = j + 1
print calendar.timegm(time.gmtime())
print virkedeDet

# %%
try:
    query = "https://api.themoviedb.org/3/movie/" + IMDB[1] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[2] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[3] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[4] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[5] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[6] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[7] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[8] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[9] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[10] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[11] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[12] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[13] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[14] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[15] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[16] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[17] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[18] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[19] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[20] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[21] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[22] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[23] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[24] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[25] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[26] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[27] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[28] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[29] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[30] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[31] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[32] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[33] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[34] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[35] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[36] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[37] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[38] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[39] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[40] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[41] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
    query = "https://api.themoviedb.org/3/movie/" + IMDB[42] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
    wikiresponse = urllib2.urlopen(query)
    sidensJson = json.load(wikiresponse)
except HTTPError:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-7dfce1b11a3c> in <module>()
#     126     wikiresponse = urllib2.urlopen(query)
#     127     sidensJson = json.load(wikiresponse)
# --> 128 except HTTPError:
#     129     pass
#
# NameError: name 'HTTPError' is not defined

# %%
query = "https://api.themoviedb.org/3/movie/" + IMDB[1] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
wikiresponse = urllib2.urlopen(query)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-92-b98d48048e71> in <module>()
#       1 query = "https://api.themoviedb.org/3/movie/" + IMDB[1] + "?api_key=165c6cb5ab10a81562b9e48c4dff4665&language=en-US"
# ----> 2 wikiresponse = urllib2.urlopen(query)
#
# C:\Users\masta\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\masta\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# ...
